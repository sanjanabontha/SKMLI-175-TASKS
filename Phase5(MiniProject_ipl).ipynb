# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanabontha/SKMLI-175-TASKS/blob/main/Phase5(MiniProject_ipl).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import joblib

# Step 1: Data Collection
# Load the dataset
data = pd.read_csv('/content/ipl_score_predictor_data.csv')
print(data.head(8))
print(data.columns)
print(data.shape)

# Step 2: Data Preprocessing
X = data.drop('winner', axis=1)
y = data['winner']

# Standardization
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 3: Model Selection and Training

# Logistic Regression
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)
y_pred_logistic = logistic_model.predict(X_test)

feature_names = X.columns
# Random Forest
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# Gradient Boosting Classifier
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(X_train, y_train)
y_pred_gb = gb_model.predict(X_test)

# Deep Learning Model using Neural Networks
dl_model = Sequential([
    tf.keras.Input(shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])
dl_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
dl_model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.1, verbose=1)
y_pred_dl = (dl_model.predict(X_test) > 0.5).astype("int32").flatten()

# Step 4: Model Evaluation

def evaluate_model(y_test, y_pred, model_name):
    print(f"--- {model_name} ---")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
    print(f"Precision: {precision_score(y_test, y_pred):.2f}")
    print(f"Recall: {recall_score(y_test, y_pred):.2f}")
    print(f"F1 Score: {f1_score(y_test, y_pred):.2f}")
    print("Confusion Matrix:")
    conf_matrix = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(6, 4))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{model_name} Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()
    print("\n")

# Evaluate all models
evaluate_model(y_test, y_pred_logistic, "Logistic Regression")
evaluate_model(y_test, y_pred_rf, "Random Forest")
evaluate_model(y_test, y_pred_gb, "Gradient Boosting")
evaluate_model(y_test, y_pred_dl, "Deep Learning Model")

# Step 5: Hyperparameter Tuning for RandomForest
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [5, 10, 15, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_rf_model = grid_search.best_estimator_

# Evaluate the best model
y_pred_best_rf = best_rf_model.predict(X_test)
evaluate_model(y_test, y_pred_best_rf, "Best Random Forest")

# Step 6: Save the Best Model
joblib.dump(best_rf_model, 'ipl_score_predictor_rf.pkl')

# Example of loading the model and making predictions
loaded_model = joblib.load('ipl_score_predictor_rf.pkl')
example_prediction = loaded_model.predict(X_test[:1])
print('Example Prediction after loading the model:', example_prediction)
print('\n')


def predict_match_outcome(match_situation):
    match_data = pd.DataFrame([match_situation])
    match_data['batting_team'] = match_data['batting_team'].astype('category').cat.codes
    match_data['bowling_team'] = match_data['bowling_team'].astype('category').cat.codes

    # Random Forest predictions
    rf_probabilities = rf_model.predict_proba(match_data)
    print(f"Random Forest Probability of Winning for Team 1: {rf_probabilities[0, 0] * 100:.2f}%")
    print(f"Random Forest Probability of Winning for Team 2: {rf_probabilities[0, 1] * 100:.2f}%")

    # Deep Learning predictions
    dl_probability = dl_model.predict(match_data)[0][0]
    print(f"Deep Learning Probability of Winning for Team 1: {dl_probability * 100:.2f}%")
    print(f"Deep Learning Probability of Winning for Team 2: {(1 - dl_probability) * 100:.2f}%")

    runs_scored = match_situation['current_run_rate'] * match_situation['over']
    predicted_final_score = runs_scored + (match_situation['runs_remaining'] / (1 - dl_probability))
    print(f"Estimated Final Score: {predicted_final_score:.2f}")

import matplotlib.pyplot as plt
from sklearn.calibration import calibration_curve

# Assuming `model` is your Random Forest model and `dl_model` is your Deep Learning model
# Define predictions for Random Forest and Deep Learning models
y_pred_rf = rf_model.predict(X_test)
y_pred_dl = (dl_model.predict(X_test) > 0.5).astype(int).flatten()  # Ensure binary predictions

# Define predicted probabilities
rf_probabilities = rf_model.predict_proba(X_test)[:, 1]  # Probability estimates for class 1
dl_probabilities = dl_model.predict(X_test).flatten()  # Assuming it gives probabilities for class 1

# Create a DataFrame to compare predictions
comparison_df = pd.DataFrame({
    'Actual': y_test,
    'RF_Pred': y_pred_rf,
    'DL_Pred': y_pred_dl,
    'RF_Prob': rf_probabilities,
    'DL_Prob': dl_probabilities
})
print(comparison_df.head(10))

# Function to plot calibration curves
def plot_calibration_curve(probabilities, true_labels, model_name):
    fraction_of_positives, mean_predicted_value = calibration_curve(true_labels, probabilities, n_bins=10)
    plt.plot(mean_predicted_value, fraction_of_positives, marker='o', label=model_name)

# Plot calibration curves for both models
plt.figure(figsize=(10, 7))
plot_calibration_curve(rf_probabilities, y_test, 'Random Forest')
plot_calibration_curve(dl_probabilities, y_test, 'Deep Learning')
plt.xlabel('Mean Predicted Probability')
plt.ylabel('Fraction of Positives')
plt.title('Calibration Curve')
plt.legend()
plt.show()
print('\n')

# Example usage
match_situation = {
    'match_id': 1,
    'batting_team': 2,
    'bowling_team': 4,
    'current_run_rate': 7.5,
    'wickets_remaining': 5,
    'runs_remaining': 60,
    'over': 15,
    'avg_runs': 150,
    'total_wickets': 10,
    'innings': 2
}

# Load the best model and scaler
loaded_model = joblib.load('ipl_score_predictor_rf.pkl')

# Example of predicting the winning probability
winning_prob, predicted_class = predict_winning_probability(loaded_model, match_situation, scaler)
print(f'Winning Probability: {winning_prob * 100:.2f}%')
print(f'Predicted Class: {predicted_class} (1 means win, 0 means lose)')
print("Final Probabilities and Scoreline:")
predict_match_outcome(match_situation)
# Out:
#    match_id  batting_team  bowling_team  current_run_rate  wickets_remaining  \
# 0       103             2             1          5.591214                  6
# 1       436             4             1          5.463938                  4
# 2       861             8             2          9.838063                  5
# 3       271             7             2          6.358586                  6
# 4       107             9             6          9.352279                  2
# 5        72             8             7          7.786832                  9
# 6       701             5             5          8.768868                  2
# 7        21             2             1          7.015823                  4
#
#    runs_remaining       over    avg_runs  total_wickets  innings  winner
# 0              98  14.884233  193.220574              5        2       0
# 1             104  13.620789  173.208460              4        1       0
# 2              29   4.750129  198.632391              8        2       1
# 3              16   8.004458  172.566149              0        2       1
# 4             112   9.554298  174.565103              4        2       0
# 5              61   1.657826  168.837093              5        1       1
# 6              83  10.567402  136.370146              4        1       1
# 7             111   8.726717  180.847792              5        2       0
# Index(['match_id', 'batting_team', 'bowling_team', 'current_run_rate',
#        'wickets_remaining', 'runs_remaining', 'over', 'avg_runs',
#        'total_wickets', 'innings', 'winner'],
#       dtype='object')
# (100, 11)
# Epoch 1/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - accuracy: 0.4325 - loss: 0.7354 - val_accuracy: 0.1250 - val_loss: 0.7871
# Epoch 2/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4875 - loss: 0.7316 - val_accuracy: 0.1250 - val_loss: 0.7754
# Epoch 3/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5615 - loss: 0.6923 - val_accuracy: 0.1250 - val_loss: 0.7753
# Epoch 4/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5169 - loss: 0.7068 - val_accuracy: 0.2500 - val_loss: 0.7674
# Epoch 5/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5620 - loss: 0.6869 - val_accuracy: 0.2500 - val_loss: 0.7652
# Epoch 6/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6270 - loss: 0.6672 - val_accuracy: 0.2500 - val_loss: 0.7701
# Epoch 7/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6746 - loss: 0.6542 - val_accuracy: 0.2500 - val_loss: 0.7691
# Epoch 8/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6364 - loss: 0.6464 - val_accuracy: 0.3750 - val_loss: 0.7643
# Epoch 9/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6675 - loss: 0.6356 - val_accuracy: 0.3750 - val_loss: 0.7634
# Epoch 10/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6868 - loss: 0.6390 - val_accuracy: 0.2500 - val_loss: 0.7620
# Epoch 11/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7423 - loss: 0.6073 - val_accuracy: 0.2500 - val_loss: 0.7658
# Epoch 12/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7492 - loss: 0.6147 - val_accuracy: 0.2500 - val_loss: 0.7696
# Epoch 13/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7595 - loss: 0.6220 - val_accuracy: 0.2500 - val_loss: 0.7669
# Epoch 14/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6999 - loss: 0.6085 - val_accuracy: 0.2500 - val_loss: 0.7625
# Epoch 15/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7674 - loss: 0.6111 - val_accuracy: 0.3750 - val_loss: 0.7630
# Epoch 16/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8248 - loss: 0.5680 - val_accuracy: 0.3750 - val_loss: 0.7609
# Epoch 17/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7861 - loss: 0.5893 - val_accuracy: 0.3750 - val_loss: 0.7615
# Epoch 18/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7781 - loss: 0.5679 - val_accuracy: 0.3750 - val_loss: 0.7562
# Epoch 19/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8362 - loss: 0.5615 - val_accuracy: 0.5000 - val_loss: 0.7532
# Epoch 20/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8040 - loss: 0.5702 - val_accuracy: 0.5000 - val_loss: 0.7531
# Epoch 21/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8543 - loss: 0.5432 - val_accuracy: 0.5000 - val_loss: 0.7608
# Epoch 22/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7865 - loss: 0.5509 - val_accuracy: 0.5000 - val_loss: 0.7727
# Epoch 23/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7699 - loss: 0.5377 - val_accuracy: 0.3750 - val_loss: 0.7834
# Epoch 24/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8296 - loss: 0.5310 - val_accuracy: 0.5000 - val_loss: 0.7839
# Epoch 25/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7592 - loss: 0.5429 - val_accuracy: 0.5000 - val_loss: 0.7838
# Epoch 26/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8079 - loss: 0.5115 - val_accuracy: 0.5000 - val_loss: 0.7839
# Epoch 27/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8154 - loss: 0.5070 - val_accuracy: 0.3750 - val_loss: 0.7761
# Epoch 28/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7801 - loss: 0.5179 - val_accuracy: 0.3750 - val_loss: 0.7750
# Epoch 29/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8066 - loss: 0.4864 - val_accuracy: 0.3750 - val_loss: 0.7874
# Epoch 30/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8427 - loss: 0.4913 - val_accuracy: 0.2500 - val_loss: 0.7971
# Epoch 31/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8088 - loss: 0.4974 - val_accuracy: 0.2500 - val_loss: 0.7961
# Epoch 32/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8862 - loss: 0.4569 - val_accuracy: 0.3750 - val_loss: 0.8005
# Epoch 33/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9063 - loss: 0.4524 - val_accuracy: 0.2500 - val_loss: 0.8079
# Epoch 34/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9074 - loss: 0.4298 - val_accuracy: 0.3750 - val_loss: 0.8066
# Epoch 35/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9161 - loss: 0.4240 - val_accuracy: 0.3750 - val_loss: 0.8014
# Epoch 36/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8755 - loss: 0.4665 - val_accuracy: 0.3750 - val_loss: 0.7955
# Epoch 37/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8702 - loss: 0.4296 - val_accuracy: 0.3750 - val_loss: 0.7922
# Epoch 38/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8652 - loss: 0.4191 - val_accuracy: 0.3750 - val_loss: 0.7992
# Epoch 39/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8637 - loss: 0.4323 - val_accuracy: 0.3750 - val_loss: 0.8018
# Epoch 40/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9010 - loss: 0.4037 - val_accuracy: 0.3750 - val_loss: 0.8075
# Epoch 41/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8956 - loss: 0.4161 - val_accuracy: 0.3750 - val_loss: 0.8161
# Epoch 42/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8627 - loss: 0.4374 - val_accuracy: 0.3750 - val_loss: 0.8220
# Epoch 43/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9063 - loss: 0.3961 - val_accuracy: 0.3750 - val_loss: 0.8247
# Epoch 44/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8928 - loss: 0.3954 - val_accuracy: 0.3750 - val_loss: 0.8179
# Epoch 45/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9276 - loss: 0.3442 - val_accuracy: 0.3750 - val_loss: 0.8181
# Epoch 46/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9132 - loss: 0.3757 - val_accuracy: 0.5000 - val_loss: 0.8212
# Epoch 47/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9214 - loss: 0.3505 - val_accuracy: 0.5000 - val_loss: 0.8177
# Epoch 48/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8864 - loss: 0.3722 - val_accuracy: 0.5000 - val_loss: 0.8094
# Epoch 49/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9246 - loss: 0.3374 - val_accuracy: 0.5000 - val_loss: 0.8120
# Epoch 50/50
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8906 - loss: 0.3577 - val_accuracy: 0.5000 - val_loss: 0.8132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# --- Logistic Regression ---
# Accuracy: 0.60
# Precision: 0.50
# Recall: 0.38
# F1 Score: 0.43
# Confusion Matrix:
# --- Random Forest ---
# Accuracy: 0.60
# Precision: 0.50
# Recall: 0.50
# F1 Score: 0.50
# Confusion Matrix:
# --- Gradient Boosting ---
# Accuracy: 0.45
# Precision: 0.29
# Recall: 0.25
# F1 Score: 0.27
# Confusion Matrix:
# --- Deep Learning Model ---
# Accuracy: 0.55
# Precision: 0.45
# Recall: 0.62
# F1 Score: 0.53
# Confusion Matrix:
# --- Best Random Forest ---
# Accuracy: 0.60
# Precision: 0.50
# Recall: 0.50
# F1 Score: 0.50
# Confusion Matrix:
# Example Prediction after loading the model: [0]
#
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#     Actual  RF_Pred  DL_Pred  RF_Prob   DL_Prob
# 83       0        0        0     0.32  0.203557
# 53       0        1        1     0.66  0.603733
# 70       0        0        1     0.30  0.526057
# 45       0        0        0     0.38  0.450395
# 44       0        0        0     0.26  0.474588
# 39       1        0        1     0.43  0.505610
# 22       0        1        1     0.58  0.919360
# 80       0        1        1     0.71  0.932804
# 10       1        0        0     0.22  0.175210
# 0        0        0        0     0.08  0.149088
# Winning Probability: 49.25%
# Predicted Class: 0 (1 means win, 0 means lose)
# Final Probabilities and Scoreline:
# Random Forest Probability of Winning for Team 1: 52.00%
# Random Forest Probability of Winning for Team 2: 48.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Deep Learning Probability of Winning for Team 1: 0.00%
# Deep Learning Probability of Winning for Team 2: 100.00%
# Estimated Final Score: 172.50
